# %%
import pandas as pd
import numpy as np
from scipy import io
from scipy import sparse
import sys
import logging
import seaborn 
import matplotlib.pyplot as plt
from IPython.display import display, Math, Latex
from time import time

from sklearn import metrics
from sklearn.metrics.pairwise import linear_kernel,pairwise_distances
from sklearn.feature_extraction import text as txt
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer, HashingVectorizer
from sklearn import decomposition
from operator import itemgetter
from sklearn.naive_bayes import MultinomialNB


from sklearn.pipeline import Pipeline
from sklearn.preprocessing import Normalizer
from sklearn.cluster import KMeans, MiniBatchKMeans, AffinityPropagation

from optparse import OptionParser

import bs4 as bs4
import re, sys

from nltk import word_tokenize          
from nltk.stem import WordNetLemmatizer
from nltk.tokenize.regexp import WordPunctTokenizer
import nltk

import gensim
from gensim import corpora, similarities, models
from gensim import matutils

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
description = pd.read_csv("/Users/bwu/testing/austin_luxury_desc_2015.csv", 
                          header = None, 
                          names = ["description"],
                          delimiter = "\n", encoding = "ISO-8859-1")

# %%
description.head()
# Out:
#                                          description
# 0  ï»¿New Drees Custom Home In beautiful Sweetwat...
# 1  Patterned after Andrew Palladios famous Villa ...
# 2  Executive three story home in Bella Lago with ...
# 3  Magical parcel of land on a deep water cove. C...
# 4  Mediterranean estate home in gated Vineyard Ba...

# %%
#Text Cleaning Functions
def mrclean(text):
    '''
    NAME
            mrclean
    SYNOPSIS
            Cleans incoming text
    DESCRIPTION
            Removes all untranslatable unicode
    '''
    c = ['\xe2','\x80','\x93','\xc2','\xa0','\n', '\r', '\u2019', '\n\n', '\x96']  
    return re.sub('[%s]' % ''.join(c), '', text)

def soupText(eText):
    '''
    NAME
            soupText

    SYNOPSIS
            Removes all the HTML tags using BeautifulSoup

    DESCRIPTION
            Explicitly calls utf-8, replaces all double quotes with single and calls on helper function mrclean
    '''
    eText = str(eText.encode("utf-8").replace("'",'"') )
    soup = bs4.BeautifulSoup(eText)
    cleanText = soup.findAll(text=True)  #.get_text()
    return mrclean(''.join(cleanText))

# %%
#Stopwords specific to property descriptions 
additional_stop_words = []

# %%
grouped_descriptions = []
for y in description["description"]:
    w = ''.join([i if ord(i) < 128 else '' for i in y])
    unicode(w)
    soupText(w)
    grouped_descriptions.append(w)
# Out:
# /usr/local/lib/python2.7/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
len(grouped_descriptions)
# Out:
# 27175

# %%
n_samples = len(grouped_descriptions)
n_features = 10000

tfidf = TfidfVectorizer(min_df = 10, 
                         #max_df =.99,
                         max_features = n_features, 
                         stop_words = txt.ENGLISH_STOP_WORDS.union(additional_stop_words),
                         sublinear_tf=True,
                         ngram_range=(1,3),
                         )

counts = tfidf.fit_transform(grouped_descriptions)
X = TfidfTransformer().fit_transform(counts)

print X.shape
print len(grouped_descriptions)
print type(X)
X_transformed = X.T
print X_transformed.shape
# Out:
# (27175, 10000)
# 27175
# <class 'scipy.sparse.csr.csr_matrix'>
# (10000, 27175)

# %%
#NMF for grouped comments
n_topics = 25
n_top_words = 15

print("size of corpus: {}".format(len(grouped_descriptions)))

t0 = time()

# Fit the NMF model
print("Fitting the NMF model on with n_samples=%d and n_features=%d..."
      % (n_samples, X.shape[1]))
nmf = decomposition.NMF(n_components=n_topics).fit(X)
print("done in %0.3fs." % (time() - t0))

# Inverse the vectorizer vocabulary to be able
feature_names = tfidf.get_feature_names()

for topic_idx, topic in enumerate(nmf.components_):
    print("Topic #%d:" % topic_idx)
    print(" ".join( [feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]] ))
    print
# Out:
# size of corpus: 27175
# Fitting the NMF model on with n_samples=27175 and n_features=10000...
# done in 57.119s.
# Topic #0:
# room granite master bath large fireplace game patio suite area stainless formal kitchen breakfast game room
#
# Topic #1:
# bridgeport bridgeport home elegant leads sun invites friends family invites friends mls 9450377 built mls 9450377 portico leads floorplan combines portico leads sun entertainments floorplan combines gourmet new face luxury family room airy living bridgeport home
#
# Topic #2:
# 04 urban known energy efficient known energy experience best austin neighborhood experience best neighborhood experience urban neighborhood experience prestigious 04 urban prestigious 04 04 urban neighborhood best austin offer experience best intimate homes 15 intimate 15 intimate homes
#
# Topic #3:
# ready story downstairs baths powder 4484518 built 4484518 baths powder bath powder bath entry story lakeridge story lakeridge home ready story lakeridge lakeridge home includes lakeridge home lakeridge bath entry dining breakfast nook loft utility room breakfast
#
# Topic #4:
# sleek interiors brilliantly interiors brilliantly blend interiors brilliantly known impeccable stone exterior sleek stone premier stone premier thermador charming classic charming classic elements boasting design qualities city living heart boasting design blend charming classic classic elements blend charming
#
# Topic #5:
# suite outdoor fireplace furniture style cabinets story plans storage furniture style storage furniture plans unique plans unique ceiling treatments look treatments look kitchen mls 4905613 built largest story largest story plans mls 4905613 unique ceiling treatments cabinets extended
#
# Topic #6:
# beautiful lady bird twin oaks library additional income ability build rental gaining build rental unit build rental beautiful lady library hike patio slab springs pool shops main roof twin oaks unit utilizing library hike bike
#
# Topic #7:
# lady bird lady lady bird lake bird lake bird concierge unit parking parking spaces 24 fitness condo hike bike trail bike trail bike
#
# Topic #8:
# features bedrooms bath new section circle backs private green section circle new section private green space designs flow indoors designs flow home buyer crafted walk new pool rated walk addition spacious buyer crafted spacious buyer crafted rated walk new
#
# Topic #9:
# amenities including burner open spaces flow features gourmet amenities lighting double ovens function luxury function luxury mind flow function flow function luxury gourmet amenities including gourmet amenities cabinet lighting double spaces flow function kitchen features gourmet spaces flow lighting double
#
# Topic #10:
# aegb community aegb solar spray foam solar spray modern quality modern quality finishes insulation included energy community northwest community northwest hills downtown minutes great quality finishes inclusive minutes great restaurants insulation included foam insulation included finishes inclusive
#
# Topic #11:
# western sliders sliders ram windows ram toilets moen showers moen showers duravit toilets moen toilets moen duravit toilets fixtures duravit grohe fixtures duravit fixtures duravit toilets moen oak plank flooring duravit
#
# Topic #12:
# 512 784 784 jeannette spinelli 512 spinelli 512 contact jeannette 784 8022 spinelli 512 784 contact jeannette spinelli jeannette spinelli jeannette 512 784 8022 8022 spinelli information visit www
#
# Topic #13:
# end coveted cul contemporary residences stunning new development development sits development sits perched features contemporary residences new development sits sac barton springs springs features barton springs features end coveted springs features contemporary heart austin zilker residences heart austin coveted cul sac
#
# Topic #14:
# porches unobstructed house law millennium featuring modern house law apartments millennium featuring complete antique washer pits washer pits bocce eastside bars restaurants new millennium featuring eastside bars bocce robert carter luxurious estate architect greens washer pits
#
# Topic #15:
# tankless heater tankless water water heater tankless water heater insulation foam foam insulation water spray spray foam spray foam insulation energy low windows hvac
#
# Topic #16:
# waterfront boat lake dock lake travis boat dock lake austin travis slip travis waterfront lake travis waterfront views lake water acres main body
#
# Topic #17:
# house austin property original downtown location sq lot park sq ft minutes ft opportunity just lots
#
# Topic #18:
# drees new drees drees custom new drees custom drees custom home rocky creek rocky bedrooms upstairs builds energy builds energy efficient drees builds energy drees builds efficient homes competition homes competition sweetwater
#
# Topic #19:
# pacific homes standard pacific homes pacific standard pacific built standard built standard pacific standard mls trees elegant stone 9809128 9809128 built 9809128 built standard mls 9809128 game room 200 home lush landscaping
#
# Topic #20:
# tumbled carrera sinks recessed lighting kohler sinks recessed carports duravit showers carrera floors silestone quartz tumbled study creates spacious study creates open floorplan kitchen sinks recessed interior luxurious foot ceilings dedicated hansgrohe fixtures open creates spacious interior ceilings dedicated
#
# Topic #21:
# zilker park zilker south lamar downtown south lamar distance downtown south south lamar zilker lamar zilker park lamar zilker biking distance downtown location biking location biking distance prime location biking situated renowned austin school district steps austin independent school
#
# Topic #22:
# golf barton creek course golf course country hill country creek hill barton club country club creek country creek country club barton creek country hill country views
#
# Topic #23:
# subway tile subway white subway white subway tile heritage live cold rolled cold rolled steel rolled steel rolled cold european fixtures european inside open open plan consistent
#
# Topic #24:
# desk planning desk beams desk beams desk beams family beams family planning desk planning built highland built highland homes highland homes custom finishes highland homes ready floor outdoor fireplace computer desk bookshelves wooded acres new

# %%
for topic_idx, topic in enumerate(nmf.components_):

    words = [feature_names[i] for i in topic.argsort()[:-(n_top_words):-1]]
    scores = [topic[i] for i in topic.argsort()[:-(n_top_words):-1]]

    dicta = {word: score for score, word in zip(scores, words)}
    
    s = pd.Series(dicta)
    t = s.order(ascending=False)

    plt.figure()
    plt.title("Topic #%d:" % topic_idx)
    t.plot(kind='bar');
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/pyplot.py:424: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
#Word clouds
import vincent
vincent.core.initialize_notebook()

topics_dicts = []
H = nmf.components_
n_topics = nmf.n_components_
feature_names = tfidf.get_feature_names()

for i in xrange(n_topics):
    # n_top_words of keys and values
    keys, values = zip(*sorted(zip(feature_names, H[i]), key = lambda x: x[1])[:-n_top_words:-1])
    val_arr = np.array(values)
    norms = val_arr / np.sum(val_arr)
    #normalize = lambda x: int(x / (max(counter.values()) - min(counter.values())) * 90 + 10)
    topics_dicts.append(dict(zip(keys, np.rint(norms* 300))))

for i in xrange(n_topics):
    word_cloud = vincent.Word(topics_dicts[i])
    word_cloud.width = 300
    word_cloud.height = 300
    word_cloud.padding = 0
    word_cloud.data[0].transform[0].rotate['random'] = [-90,0]
    word_cloud.display();
#     word_cloud.to_json('static/bar%d.json' % i, html_out=True, html_path='bar_template.html')
# Out:
#            <script>
#
#                 function vct_load_lib(url, callback){
#                       if(typeof d3 !== 'undefined' &&
#                          url === 'http://d3js.org/d3.v3.min.js'){
#                         callback()
#                       }
#                       var s = document.createElement('script');
#                       s.src = url;
#                       s.async = true;
#                       s.onreadystatechange = s.onload = callback;
#                       s.onerror = function(){
#                         console.warn("failed to load library " + url);
#                         };
#                       document.getElementsByTagName("head")[0].appendChild(s);
#                 };
#                 var vincent_event = new CustomEvent(
#                   "vincent_libs_loaded",
#                   {bubbles: true, cancelable: true}
#                 );
#
#                function load_all_libs(){
#                   console.log('Loading Vincent libs...')
#                   vct_load_lib('http://d3js.org/d3.v3.min.js', function(){
#                   vct_load_lib('http://d3js.org/d3.geo.projection.v0.min.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/d3-cloud/d3.layout.cloud.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/vega/vega.v1.3.3.js', function(){
#                   window.dispatchEvent(vincent_event);
#                   });
#                   });
#                   });
#                   });
#                };
#                if(typeof define === "function" && define.amd){
#                     if (window['d3'] === undefined ||
#                         window['topojson'] === undefined){
#                         require.config(
#                             {paths: {
#                               d3: 'http://d3js.org/d3.v3.min',
#                               topojson: 'http://d3js.org/topojson.v1.min'
#                               }
#                             }
#                           );
#                         require(["d3"], function(d3){
#                             console.log('Loading Vincent from require.js...')
#                             window.d3 = d3;
#                             require(["topojson"], function(topojson){
#                                 window.topojson = topojson;
#                                 load_all_libs();
#                             });
#                         });
#                     } else {
#                         load_all_libs();
#                     };
#                }else{
#                     console.log('Require.js not found, loading manually...')
#                     load_all_libs();
#                };
#
#            </script>
# <div id="vis62fe6e4b3e91476888d16a876b0599c8"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, 0]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "area", "val": 20.0}, {"col": "data", "idx": "bath", "val": 22.0}, {"col": "data", "idx": "breakfast", "val": 20.0}, {"col": "data", "idx": "fireplace", "val": 21.0}, {"col": "data", "idx": "formal", "val": 20.0}, {"col": "data", "idx": "game", "val": 21.0}, {"col": "data", "idx": "granite", "val": 24.0}, {"col": "data", "idx": "kitchen", "val": 20.0}, {"col": "data", "idx": "large", "val": 22.0}, {"col": "data", "idx": "master", "val": 22.0}, {"col": "data", "idx": "patio", "val": 21.0}, {"col": "data", "idx": "room", "val": 27.0}, {"col": "data", "idx": "stainless", "val": 20.0}, {"col": "data", "idx": "suite", "val": 21.0}]}], "height": 300, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 300}, function(chart) {
#          chart({el: "#vis62fe6e4b3e91476888d16a876b0599c8"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="vis5b7b4fec348b440eab84d62427192486"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, 0]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "bridgeport", "val": 35.0}, {"col": "data", "idx": "new face luxury", "val": 20.0}, {"col": "data", "idx": "open floorplan combines", "val": 20.0}, {"col": "data", "idx": "perfect everyday", "val": 20.0}, {"col": "data", "idx": "perfect everyday living", "val": 20.0}, {"col": "data", "idx": "portico", "val": 20.0}, {"col": "data", "idx": "portico leads", "val": 20.0}, {"col": "data", "idx": "portico leads sun", "val": 20.0}, {"col": "data", "idx": "ready come look", "val": 20.0}, {"col": "data", "idx": "room airy", "val": 20.0}, {"col": "data", "idx": "room airy breakfast", "val": 20.0}, {"col": "data", "idx": "stately home perfect", "val": 20.0}, {"col": "data", "idx": "sun dappled", "val": 20.0}, {"col": "data", "idx": "sun dappled courtyard", "val": 20.0}]}], "height": 300, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 300}, function(chart) {
#          chart({el: "#vis5b7b4fec348b440eab84d62427192486"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="visb5f5c1124448427d82e6ea4ba32bfd21"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, 0]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "04 urban", "val": 22.0}, {"col": "data", "idx": "04 urban neighborhood", "val": 21.0}, {"col": "data", "idx": "15 intimate homes", "val": 21.0}, {"col": "data", "idx": "best austin offer", "val": 21.0}, {"col": "data", "idx": "experience best", "val": 21.0}, {"col": "data", "idx": "experience best austin", "val": 21.0}, {"col": "data", "idx": "intimate homes", "val": 21.0}, {"col": "data", "idx": "known energy", "val": 22.0}, {"col": "data", "idx": "known energy efficient", "val": 22.0}, {"col": "data", "idx": "neighborhood experience", "val": 21.0}, {"col": "data", "idx": "neighborhood experience best", "val": 21.0}, {"col": "data", "idx": "prestigious 04", "val": 21.0}, {"col": "data", "idx": "prestigious 04 urban", "val": 21.0}, {"col": "data", "idx": "urban neighborhood experience", "val": 21.0}]}], "height": 300, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 300}, function(chart) {
#          chart({el: "#visb5f5c1124448427d82e6ea4ba32bfd21"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="visbe2a78888e644ecaac59581e6d7ef46a"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, 0]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "lakeridge home", "val": 21.0}, {"col": "data", "idx": "lakeridge home includes", "val": 21.0}, {"col": "data", "idx": "mls 4484518", "val": 21.0}, {"col": "data", "idx": "mls 4484518 built", "val": 21.0}, {"col": "data", "idx": "nook loft", "val": 21.0}, {"col": "data", "idx": "nook loft media", "val": 21.0}, {"col": "data", "idx": "patios covered deck", "val": 21.0}, {"col": "data", "idx": "powder bath entry", "val": 21.0}, {"col": "data", "idx": "ready story", "val": 21.0}, {"col": "data", "idx": "ready story lakeridge", "val": 21.0}, {"col": "data", "idx": "room breakfast nook", "val": 21.0}, {"col": "data", "idx": "story lakeridge", "val": 21.0}, {"col": "data", "idx": "story lakeridge home", "val": 21.0}, {"col": "data", "idx": "utility room breakfast", "val": 21.0}]}], "height": 300, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 300}, function(chart) {
#          chart({el: "#visbe2a78888e644ecaac59581e6d7ef46a"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="vis0680ed12382f41bd9c5b39378540544a"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, 0]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "premier thermador", "val": 21.0}, {"col": "data", "idx": "premier thermador stainless", "val": 21.0}, {"col": "data", "idx": "preselling built", "val": 21.0}, {"col": "data", "idx": "preselling built locally", "val": 21.0}, {"col": "data", "idx": "qualities hardwood", "val": 21.0}, {"col": "data", "idx": "qualities hardwood decorative", "val": 21.0}, {"col": "data", "idx": "sleek interiors", "val": 21.0}, {"col": "data", "idx": "sleek interiors brilliantly", "val": 21.0}, {"col": "data", "idx": "sophisticated design boasting", "val": 21.0}, {"col": "data", "idx": "stone exterior sleek", "val": 21.0}, {"col": "data", "idx": "stone premier", "val": 21.0}, {"col": "data", "idx": "stone premier thermador", "val": 21.0}, {"col": "data", "idx": "superior design luxurious", "val": 21.0}, {"col": "data", "idx": "tile stone premier", "val": 21.0}]}], "height": 300, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 300}, function(chart) {
#          chart({el: "#vis0680ed12382f41bd9c5b39378540544a"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="vis3bf4ae43bac54dc4af377210de264479"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, 0]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "mls 4905613 built", "val": 21.0}, {"col": "data", "idx": "plans unique", "val": 21.0}, {"col": "data", "idx": "plans unique ceiling", "val": 21.0}, {"col": "data", "idx": "ready largest", "val": 21.0}, {"col": "data", "idx": "ready largest story", "val": 21.0}, {"col": "data", "idx": "storage furniture", "val": 21.0}, {"col": "data", "idx": "storage furniture style", "val": 21.0}, {"col": "data", "idx": "story plans", "val": 21.0}, {"col": "data", "idx": "story plans unique", "val": 21.0}, {"col": "data", "idx": "style cabinets extended", "val": 21.0}, {"col": "data", "idx": "suite outdoor fireplace", "val": 21.0}, {"col": "data", "idx": "treatments look", "val": 21.0}, {"col": "data", "idx": "treatments look kitchen", "val": 21.0}, {"col": "data", "idx": "unique ceiling treatments", "val": 21.0}]}], "height": 300, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 300}, function(chart) {
#          chart({el: "#vis3bf4ae43bac54dc4af377210de264479"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="visae28ef8da2904b3da3bf7e44881385a3"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, 0]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "pool shops restaurants", "val": 21.0}, {"col": "data", "idx": "potential expand", "val": 21.0}, {"col": "data", "idx": "rental unit utilizing", "val": 21.0}, {"col": "data", "idx": "space upstairs gaining", "val": 21.0}, {"col": "data", "idx": "springs pool shops", "val": 21.0}, {"col": "data", "idx": "study floor master", "val": 21.0}, {"col": "data", "idx": "trails beautiful", "val": 21.0}, {"col": "data", "idx": "trails beautiful lady", "val": 21.0}, {"col": "data", "idx": "twin oaks", "val": 21.0}, {"col": "data", "idx": "twin oaks library", "val": 21.0}, {"col": "data", "idx": "unit utilizing", "val": 21.0}, {"col": "data", "idx": "unit utilizing existing", "val": 21.0}, {"col": "data", "idx": "upstairs gaining", "val": 21.0}, {"col": "data", "idx": "utilizing existing", "val": 21.0}]}], "height": 300, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 300}, function(chart) {
#          chart({el: "#visae28ef8da2904b3da3bf7e44881385a3"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="vis5a5c909a8e0c4b79ba73babea7874f13"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, 0]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "24", "val": 18.0}, {"col": "data", "idx": "bike trail", "val": 16.0}, {"col": "data", "idx": "bird", "val": 27.0}, {"col": "data", "idx": "bird lake", "val": 27.0}, {"col": "data", "idx": "concierge", "val": 20.0}, {"col": "data", "idx": "condo", "val": 16.0}, {"col": "data", "idx": "fitness", "val": 17.0}, {"col": "data", "idx": "hike bike trail", "val": 16.0}, {"col": "data", "idx": "lady", "val": 28.0}, {"col": "data", "idx": "lady bird", "val": 28.0}, {"col": "data", "idx": "lady bird lake", "val": 27.0}, {"col": "data", "idx": "parking", "val": 20.0}, {"col": "data", "idx": "parking spaces", "val": 19.0}, {"col": "data", "idx": "unit", "val": 20.0}]}], "height": 300, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 300}, function(chart) {
#          chart({el: "#vis5a5c909a8e0c4b79ba73babea7874f13"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="vis123663b2af2d4794aa1ddc785bea11c6"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, 0]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "backs private green", "val": 22.0}, {"col": "data", "idx": "features bedrooms bath", "val": 22.0}, {"col": "data", "idx": "new section", "val": 22.0}, {"col": "data", "idx": "new section circle", "val": 22.0}, {"col": "data", "idx": "private green space", "val": 21.0}, {"col": "data", "idx": "section circle", "val": 22.0}, {"col": "data", "idx": "space energy star", "val": 21.0}, {"col": "data", "idx": "spacious designs", "val": 21.0}, {"col": "data", "idx": "spacious designs flow", "val": 21.0}, {"col": "data", "idx": "star rated walk", "val": 21.0}, {"col": "data", "idx": "vazzano", "val": 21.0}, {"col": "data", "idx": "vazzano perfect", "val": 21.0}, {"col": "data", "idx": "vazzano perfect multifunctional", "val": 21.0}, {"col": "data", "idx": "walk new pool", "val": 21.0}]}], "height": 300, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 300}, function(chart) {
#          chart({el: "#vis123663b2af2d4794aa1ddc785bea11c6"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="vis8434b1a58f094aaaa8d498347ac1aeac"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, 0]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "amenities including burner", "val": 21.0}, {"col": "data", "idx": "cabinet lighting double", "val": 21.0}, {"col": "data", "idx": "features gourmet amenities", "val": 21.0}, {"col": "data", "idx": "flow function", "val": 21.0}, {"col": "data", "idx": "flow function luxury", "val": 21.0}, {"col": "data", "idx": "function luxury", "val": 21.0}, {"col": "data", "idx": "function luxury mind", "val": 21.0}, {"col": "data", "idx": "gourmet amenities", "val": 21.0}, {"col": "data", "idx": "gourmet amenities including", "val": 21.0}, {"col": "data", "idx": "kitchen features gourmet", "val": 21.0}, {"col": "data", "idx": "lighting double ovens", "val": 21.0}, {"col": "data", "idx": "open spaces flow", "val": 21.0}, {"col": "data", "idx": "spaces flow", "val": 21.0}, {"col": "data", "idx": "spaces flow function", "val": 21.0}]}], "height": 300, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 300}, function(chart) {
#          chart({el: "#vis8434b1a58f094aaaa8d498347ac1aeac"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="vis8a99666a2b4e458186b76964f224046f"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, 0]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "aegb", "val": 24.0}, {"col": "data", "idx": "aegb community", "val": 25.0}, {"col": "data", "idx": "modern quality", "val": 21.0}, {"col": "data", "idx": "modern quality finishes", "val": 21.0}, {"col": "data", "idx": "pricing upgrades needed", "val": 21.0}, {"col": "data", "idx": "quality finishes inclusive", "val": 21.0}, {"col": "data", "idx": "restaurants shopping solar", "val": 21.0}, {"col": "data", "idx": "savings modern", "val": 21.0}, {"col": "data", "idx": "savings modern quality", "val": 21.0}, {"col": "data", "idx": "shopping solar", "val": 21.0}, {"col": "data", "idx": "shopping solar spray", "val": 21.0}, {"col": "data", "idx": "solar spray", "val": 21.0}, {"col": "data", "idx": "solar spray foam", "val": 21.0}, {"col": "data", "idx": "upgrades needed", "val": 21.0}]}], "height": 300, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 300}, function(chart) {
#          chart({el: "#vis8a99666a2b4e458186b76964f224046f"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="vis064c6cdb3aa34278986e8f18a6844c36"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, 0]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "duravit toilets", "val": 22.0}, {"col": "data", "idx": "duravit toilets moen", "val": 22.0}, {"col": "data", "idx": "fixtures duravit", "val": 21.0}, {"col": "data", "idx": "fixtures duravit toilets", "val": 21.0}, {"col": "data", "idx": "grohe fixtures duravit", "val": 21.0}, {"col": "data", "idx": "moen", "val": 21.0}, {"col": "data", "idx": "moen showers", "val": 22.0}, {"col": "data", "idx": "oak plank flooring", "val": 20.0}, {"col": "data", "idx": "ram", "val": 22.0}, {"col": "data", "idx": "ram windows", "val": 22.0}, {"col": "data", "idx": "sliders", "val": 22.0}, {"col": "data", "idx": "toilets moen", "val": 22.0}, {"col": "data", "idx": "toilets moen showers", "val": 22.0}, {"col": "data", "idx": "western sliders", "val": 22.0}]}], "height": 300, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 300}, function(chart) {
#          chart({el: "#vis064c6cdb3aa34278986e8f18a6844c36"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="vis7e24d43503494e66958497836da8313f"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, 0]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "512 784", "val": 22.0}, {"col": "data", "idx": "512 784 8022", "val": 22.0}, {"col": "data", "idx": "784", "val": 22.0}, {"col": "data", "idx": "784 8022", "val": 22.0}, {"col": "data", "idx": "8022", "val": 22.0}, {"col": "data", "idx": "contact jeannette", "val": 22.0}, {"col": "data", "idx": "contact jeannette spinelli", "val": 22.0}, {"col": "data", "idx": "information", "val": 20.0}, {"col": "data", "idx": "jeannette", "val": 22.0}, {"col": "data", "idx": "jeannette spinelli", "val": 22.0}, {"col": "data", "idx": "jeannette spinelli 512", "val": 22.0}, {"col": "data", "idx": "spinelli", "val": 22.0}, {"col": "data", "idx": "spinelli 512", "val": 22.0}, {"col": "data", "idx": "spinelli 512 784", "val": 22.0}]}], "height": 300, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 300}, function(chart) {
#          chart({el: "#vis7e24d43503494e66958497836da8313f"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="vis6ad05956c5bc49e0bd434e9053864be1"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, 0]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "development sits", "val": 21.0}, {"col": "data", "idx": "development sits perched", "val": 21.0}, {"col": "data", "idx": "end coveted", "val": 21.0}, {"col": "data", "idx": "end coveted cul", "val": 21.0}, {"col": "data", "idx": "features contemporary residences", "val": 21.0}, {"col": "data", "idx": "heart austin zilker", "val": 21.0}, {"col": "data", "idx": "new development sits", "val": 21.0}, {"col": "data", "idx": "perched end coveted", "val": 21.0}, {"col": "data", "idx": "residences heart", "val": 21.0}, {"col": "data", "idx": "residences heart austin", "val": 21.0}, {"col": "data", "idx": "sac barton springs", "val": 21.0}, {"col": "data", "idx": "springs features", "val": 21.0}, {"col": "data", "idx": "springs features contemporary", "val": 21.0}, {"col": "data", "idx": "stunning new development", "val": 21.0}]}], "height": 300, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 300}, function(chart) {
#          chart({el: "#vis6ad05956c5bc49e0bd434e9053864be1"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="vis12c9846f13f0451a8780dfc73d9133e7"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, 0]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "new millennium featuring", "val": 21.0}, {"col": "data", "idx": "pit putting", "val": 21.0}, {"col": "data", "idx": "pit putting greens", "val": 21.0}, {"col": "data", "idx": "pits bocce", "val": 21.0}, {"col": "data", "idx": "pits bocce ball", "val": 21.0}, {"col": "data", "idx": "porches unobstructed", "val": 21.0}, {"col": "data", "idx": "putting greens", "val": 21.0}, {"col": "data", "idx": "putting greens washer", "val": 21.0}, {"col": "data", "idx": "reclaimed doors", "val": 21.0}, {"col": "data", "idx": "reclaimed doors new", "val": 21.0}, {"col": "data", "idx": "robert carter", "val": 21.0}, {"col": "data", "idx": "security sound", "val": 21.0}, {"col": "data", "idx": "washer pits", "val": 21.0}, {"col": "data", "idx": "washer pits bocce", "val": 21.0}]}], "height": 300, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 300}, function(chart) {
#          chart({el: "#vis12c9846f13f0451a8780dfc73d9133e7"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="visa0ee650ec4444cf88135b18d618c52ec"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, 0]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "energy", "val": 17.0}, {"col": "data", "idx": "foam", "val": 21.0}, {"col": "data", "idx": "foam insulation", "val": 20.0}, {"col": "data", "idx": "heater", "val": 28.0}, {"col": "data", "idx": "insulation", "val": 22.0}, {"col": "data", "idx": "low windows", "val": 15.0}, {"col": "data", "idx": "spray", "val": 18.0}, {"col": "data", "idx": "spray foam", "val": 18.0}, {"col": "data", "idx": "spray foam insulation", "val": 17.0}, {"col": "data", "idx": "tankless", "val": 29.0}, {"col": "data", "idx": "tankless water", "val": 27.0}, {"col": "data", "idx": "tankless water heater", "val": 25.0}, {"col": "data", "idx": "water", "val": 19.0}, {"col": "data", "idx": "water heater", "val": 26.0}]}], "height": 300, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 300}, function(chart) {
#          chart({el: "#visa0ee650ec4444cf88135b18d618c52ec"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="viscc343729ab404acababd00090b9532f5"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, 0]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "acres", "val": 11.0}, {"col": "data", "idx": "boat", "val": 32.0}, {"col": "data", "idx": "boat dock", "val": 25.0}, {"col": "data", "idx": "dock", "val": 28.0}, {"col": "data", "idx": "lake", "val": 32.0}, {"col": "data", "idx": "lake austin", "val": 22.0}, {"col": "data", "idx": "lake travis", "val": 25.0}, {"col": "data", "idx": "lake travis waterfront", "val": 15.0}, {"col": "data", "idx": "slip", "val": 15.0}, {"col": "data", "idx": "travis", "val": 21.0}, {"col": "data", "idx": "travis waterfront", "val": 15.0}, {"col": "data", "idx": "views lake", "val": 13.0}, {"col": "data", "idx": "water", "val": 13.0}, {"col": "data", "idx": "waterfront", "val": 33.0}]}], "height": 300, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 300}, function(chart) {
#          chart({el: "#viscc343729ab404acababd00090b9532f5"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="vis3ca3d9824e82493b976903027c830da6"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, 0]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "austin", "val": 24.0}, {"col": "data", "idx": "downtown", "val": 22.0}, {"col": "data", "idx": "ft", "val": 19.0}, {"col": "data", "idx": "house", "val": 24.0}, {"col": "data", "idx": "just", "val": 18.0}, {"col": "data", "idx": "location", "val": 22.0}, {"col": "data", "idx": "lot", "val": 21.0}, {"col": "data", "idx": "minutes", "val": 20.0}, {"col": "data", "idx": "opportunity", "val": 19.0}, {"col": "data", "idx": "original", "val": 23.0}, {"col": "data", "idx": "park", "val": 21.0}, {"col": "data", "idx": "property", "val": 23.0}, {"col": "data", "idx": "sq", "val": 21.0}, {"col": "data", "idx": "sq ft", "val": 21.0}]}], "height": 300, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 300}, function(chart) {
#          chart({el: "#vis3ca3d9824e82493b976903027c830da6"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="vis18c3daca5d664bc68903d27c31eb932c"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, 0]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "bedrooms upstairs", "val": 18.0}, {"col": "data", "idx": "builds energy", "val": 18.0}, {"col": "data", "idx": "builds energy efficient", "val": 18.0}, {"col": "data", "idx": "drees", "val": 33.0}, {"col": "data", "idx": "drees builds", "val": 18.0}, {"col": "data", "idx": "drees builds energy", "val": 18.0}, {"col": "data", "idx": "drees custom", "val": 26.0}, {"col": "data", "idx": "drees custom home", "val": 26.0}, {"col": "data", "idx": "efficient homes competition", "val": 18.0}, {"col": "data", "idx": "homes competition", "val": 18.0}, {"col": "data", "idx": "new drees", "val": 26.0}, {"col": "data", "idx": "new drees custom", "val": 26.0}, {"col": "data", "idx": "rocky", "val": 19.0}, {"col": "data", "idx": "rocky creek", "val": 19.0}]}], "height": 300, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 300}, function(chart) {
#          chart({el: "#vis18c3daca5d664bc68903d27c31eb932c"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="vis02d176d55dcd4350a802462364146ead"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, 0]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "built standard", "val": 24.0}, {"col": "data", "idx": "built standard pacific", "val": 24.0}, {"col": "data", "idx": "mls", "val": 21.0}, {"col": "data", "idx": "pacific", "val": 25.0}, {"col": "data", "idx": "pacific homes", "val": 25.0}, {"col": "data", "idx": "ready model home", "val": 18.0}, {"col": "data", "idx": "room 200", "val": 18.0}, {"col": "data", "idx": "room 200 000", "val": 18.0}, {"col": "data", "idx": "standard", "val": 24.0}, {"col": "data", "idx": "standard pacific", "val": 25.0}, {"col": "data", "idx": "standard pacific homes", "val": 25.0}, {"col": "data", "idx": "stone exterior balcony", "val": 18.0}, {"col": "data", "idx": "trees elegant", "val": 18.0}, {"col": "data", "idx": "trees elegant stone", "val": 18.0}]}], "height": 300, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 300}, function(chart) {
#          chart({el: "#vis02d176d55dcd4350a802462364146ead"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="visf523d19b64f548e9a33e371d358a95fa"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, 0]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "silestone quartz tumbled", "val": 21.0}, {"col": "data", "idx": "sinks recessed", "val": 21.0}, {"col": "data", "idx": "sinks recessed lighting", "val": 21.0}, {"col": "data", "idx": "spacious interior luxurious", "val": 21.0}, {"col": "data", "idx": "study creates", "val": 21.0}, {"col": "data", "idx": "study creates spacious", "val": 21.0}, {"col": "data", "idx": "tall windows grohe", "val": 21.0}, {"col": "data", "idx": "toilets kohler", "val": 21.0}, {"col": "data", "idx": "toilets kohler sinks", "val": 21.0}, {"col": "data", "idx": "tumbled carrera", "val": 21.0}, {"col": "data", "idx": "tumbled carrera floors", "val": 21.0}, {"col": "data", "idx": "viking appliances silestone", "val": 21.0}, {"col": "data", "idx": "windows grohe", "val": 21.0}, {"col": "data", "idx": "windows grohe hansgrohe", "val": 21.0}]}], "height": 300, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 300}, function(chart) {
#          chart({el: "#visf523d19b64f548e9a33e371d358a95fa"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="vis98cbff04c03249319e0dae1ce860e887"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, 0]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "biking distance downtown", "val": 21.0}, {"col": "data", "idx": "distance downtown south", "val": 21.0}, {"col": "data", "idx": "downtown south lamar", "val": 21.0}, {"col": "data", "idx": "lamar zilker", "val": 21.0}, {"col": "data", "idx": "lamar zilker park", "val": 21.0}, {"col": "data", "idx": "location biking", "val": 21.0}, {"col": "data", "idx": "location biking distance", "val": 21.0}, {"col": "data", "idx": "prime location biking", "val": 21.0}, {"col": "data", "idx": "situated renowned", "val": 21.0}, {"col": "data", "idx": "situated renowned austin", "val": 21.0}, {"col": "data", "idx": "south lamar", "val": 22.0}, {"col": "data", "idx": "south lamar zilker", "val": 21.0}, {"col": "data", "idx": "zilker", "val": 23.0}, {"col": "data", "idx": "zilker park", "val": 24.0}]}], "height": 300, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 300}, function(chart) {
#          chart({el: "#vis98cbff04c03249319e0dae1ce860e887"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="vis5fd126b45456408196c88e0328c09cdd"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, 0]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "barton", "val": 20.0}, {"col": "data", "idx": "barton creek", "val": 26.0}, {"col": "data", "idx": "barton creek country", "val": 18.0}, {"col": "data", "idx": "club", "val": 19.0}, {"col": "data", "idx": "country", "val": 24.0}, {"col": "data", "idx": "country club", "val": 18.0}, {"col": "data", "idx": "course", "val": 25.0}, {"col": "data", "idx": "creek", "val": 20.0}, {"col": "data", "idx": "creek country", "val": 18.0}, {"col": "data", "idx": "creek country club", "val": 18.0}, {"col": "data", "idx": "golf", "val": 29.0}, {"col": "data", "idx": "golf course", "val": 24.0}, {"col": "data", "idx": "hill", "val": 20.0}, {"col": "data", "idx": "hill country", "val": 21.0}]}], "height": 300, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 300}, function(chart) {
#          chart({el: "#vis5fd126b45456408196c88e0328c09cdd"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="vise98795078f934d409252a456788d44d7"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, 0]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "cold", "val": 20.0}, {"col": "data", "idx": "cold rolled", "val": 21.0}, {"col": "data", "idx": "cold rolled steel", "val": 21.0}, {"col": "data", "idx": "european", "val": 20.0}, {"col": "data", "idx": "european fixtures", "val": 20.0}, {"col": "data", "idx": "heritage live", "val": 21.0}, {"col": "data", "idx": "inside open", "val": 19.0}, {"col": "data", "idx": "open plan", "val": 19.0}, {"col": "data", "idx": "rolled", "val": 21.0}, {"col": "data", "idx": "rolled steel", "val": 21.0}, {"col": "data", "idx": "subway", "val": 25.0}, {"col": "data", "idx": "subway tile", "val": 25.0}, {"col": "data", "idx": "white subway", "val": 24.0}, {"col": "data", "idx": "white subway tile", "val": 24.0}]}], "height": 300, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 300}, function(chart) {
#          chart({el: "#vise98795078f934d409252a456788d44d7"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="vis52311f74acd84e93b1df45d741db6e0b"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, 0]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "beams family", "val": 23.0}, {"col": "data", "idx": "built highland", "val": 21.0}, {"col": "data", "idx": "built highland homes", "val": 21.0}, {"col": "data", "idx": "custom finishes", "val": 20.0}, {"col": "data", "idx": "desk", "val": 24.0}, {"col": "data", "idx": "desk beams", "val": 24.0}, {"col": "data", "idx": "desk beams family", "val": 24.0}, {"col": "data", "idx": "floor outdoor fireplace", "val": 19.0}, {"col": "data", "idx": "highland homes", "val": 21.0}, {"col": "data", "idx": "highland homes ready", "val": 19.0}, {"col": "data", "idx": "planning", "val": 21.0}, {"col": "data", "idx": "planning desk", "val": 23.0}, {"col": "data", "idx": "planning desk beams", "val": 24.0}, {"col": "data", "idx": "wooded acres new", "val": 18.0}]}], "height": 300, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 300}, function(chart) {
#          chart({el: "#vis52311f74acd84e93b1df45d741db6e0b"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
